# %%
import pandas as pd
import pymongo

# %%
df = pd.read_csv('E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\data/final_df_2.csv', index_col=0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\nkftt\AppData\Local\Temp\ipykernel_18444\1515051955.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv('E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\data/final_df_2.csv', index_col=0)

# %%
data = df.to_dict(orient='records')

# %%
data
# Out:
# [{'User-ID': 277427,
#   'ISBN': '002542730X',
#   'Book-Rating': 10,
#   'Book-Title': 'Politically Correct Bedtime Stories: Modern Tales for Our Life and Times',
#   'Book-Author': 'James Finn Garner',
#   'Year-Of-Publication': 1994,
#   'Publisher': 'John Wiley &amp; Sons Inc',
#   'Image-URL-S': 'http://images.amazon.com/images/P/002542730X.01.THUMBZZZ.jpg',
#   'Image-URL-M': 'http://images.amazon.com/images/P/002542730X.01.MZZZZZZZ.jpg',
#   'Image-URL-L': 'http://images.amazon.com/images/P/002542730X.01.LZZZZZZZ.jpg',
#   'num_of_reating': 171,
#   'avg_of_reating': 3.514619883040936},
#  {'User-ID': 277427,
#   'ISBN': '0060930535',
#   'Book-Rating': 0,
#   'Book-Title': 'The Poisonwood Bible: A Novel',
#   'Book-Author': 'Barbara Kingsolver',
#   'Year-Of-Publication': 1999,
#   'Publisher': 'Perennial',
#   'Image-URL-S': 'http://images.amazon.com/images/P/0060930535.01.THUMBZZZ.jpg',
#   'Image-URL-M': 'http://images.amazon.com/images/P/0060930535.01.MZZZZZZZ.jpg',
# ...

# %%
DB_NAME = 'ShelfGenieDB'
COLLECTION_NAME = 'ShelfGenie_Data'
CONNECTION_URL = 'mongodb+srv://nkftt58346:nQibUm6RWokpjiTc@cluster0.0izokts.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
client = pymongo.MongoClient(CONNECTION_URL)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
from pymongo import MongoClient
import json
import csv

client = MongoClient('mongodb+srv://nkftt58346:nQibUm6RWokpjiTc@cluster0.0izokts.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')  # Replace with your connection string
db = client['ShelfGenieDB']
collection = db['ShelfGenie_Data']
documents = collection.find({})

# %%
from pymongo.errors import ConnectionFailure, OperationFailure
try:
    client.admin.command('ping')
    print("Successfully connected to MongoDB Atlas!")

except ConnectionFailure as e:
    print(f"Connection failed: {e}")
except OperationFailure as e:
    print(f"Authentication or operation failed: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully connected to MongoDB Atlas!

# %%
from src.entity.config_entity import DataIngestionConfig
DataIngestionConfig.feature_store_folder_path
# Out:
# 'E:\\ShelfGenie-Your-next-favorite-book-powered-by-AI\\artefact\\2025-06-25 11-35-45\\data_ingestion\\feature_store\\data.csv'

# %%
first_document = documents[0]
field_names = list(first_document.keys())
with open(f'output.csv', 'w', newline='') as csvfile:
    # Create a CSV writer object
    writer = csv.DictWriter(csvfile, fieldnames=field_names)

    # Write the header row
    writer.writeheader()

    # Iterate through the documents and write each to the CSV file
    for document in documents:
        writer.writerow(document)

# %%
pd.read_csv('E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\src/notebook\output.csv',encoding='latin-1')

# %%
import os
from pathlib import Path
from from_root import from_root

# %%
results_dir = from_root('artifate')

# %%
os.makedirs(results_dir, exist_ok=True)

# %%
from src.constants import *

# %%
artefact_folder_path = from_root(ARTEFACT_DIR)
data_ingestion_folder_path = os.path.join(artefact_folder_path, DATA_INGESTION_FOLDER_NAME)

# %%
absolute_path = os.path.abspath(data_ingestion_folder_path)
os.makedirs(absolute_path, exist_ok=True)

# %%
print(artefact_folder_path)
# Out:
# E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\artefact

# %%
from datetime import datetime
TIMESTAMP: str = datetime.now().strftime("%Y-%m-%d %H-%M-%S")

# %%
artefact_folder_path: str = os.path.join(from_root(),ARTEFACT_DIR)
timestamp_folder_path: str = os.path.join(artefact_folder_path, TIMESTAMP)
data_ingestion_folder_path: str = os.path.join(timestamp_folder_path, DATA_INGESTION_FOLDER_NAME)

# %%
from pathlib import Path

# %%
path = Path(data_ingestion_folder_path)

# %%
path.mkdir(parents=True, exist_ok=True)

# %%
from src.entity.config_entity import DataIngestionConfig

# %%
DataIngestionConfig.feature_store_folder_path
# Out:
# 'E:\\ShelfGenie-Your-next-favorite-book-powered-by-AI\\artefact\\2025-06-23 17-57-52\\data_ingestion'

# %%
from src.utils.main_utils import load_yaml_file
data = load_yaml_file(os.path.join(from_root(),'config', 'schema.yaml'))
drop = data['drop_column']

# %%
type(drop)
# Out:
# list

# %%
import pandas as pd
df = pd.read_csv('E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\\artefact\\2025-06-26 11-15-46\data_ingestion\ingested\clean_data.csv',encoding='latin-1')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\nkftt\AppData\Local\Temp\ipykernel_18444\1518204040.py:2: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv('E:\ShelfGenie-Your-next-favorite-book-powered-by-AI\\artefact\\2025-06-26 11-15-46\data_ingestion\ingested\clean_data.csv',encoding='latin-1')

# %%
df.rename(columns={'Unnamed: 0' : 'Unnamed'}, inplace=True) 
df.drop(columns='Unnamed', axis=1, inplace=True)

# %%
from src.utils.main_utils import load_yaml_file
data = load_yaml_file(os.path.join(from_root(),'config', 'schema.yaml'))
drop = data['drop_column']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'User-ID', 'ISBN', 'Book-Rating', 'Book-Title',
#        'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-S',
#        'Image-URL-M', 'Image-URL-L', 'num_of_reating', 'avg_of_reating'],
#       dtype='object')

# %%
data['columns']
# Out:
# ['Unnamed: 0',
#  'User-ID',
#  'ISBN',
#  'Book-Rating',
#  'Book-Title',
#  'Book-Author',
#  'Year-Of-Publication',
#  'Publisher',
#  'Image-URL-S',
#  'Image-URL-M',
#  'Image-URL-L',
#  'num_of_reating',
#  'avg_of_reating']

# %%
list(df.columns) != data['columns']
# Out:
# False
